# %%
# 1. Импорт нужных функций из файла pipeline.py
from pipeline.pipeline import (
    create_db,
    insert_data,
    execute_queries,
    visualize_data,
    close_db,
    full_pipeline
)

# 2. Основной вызов пайплайна
full_pipeline()
# Out:
# --- Общее количество заказов ---
#    COUNT(*)
# 0       100
# --- Общий доход ---
#     revenue
# 0  73856.39
# --- Средний чек ---
#    avg_order
# 0     738.56
# --- Самый популярный товар ---
#          item  freq
# 0  Headphones    26
# --- Доход по дням ---
#     order_date  daily_revenue
# 0   2023-01-01        3000.84
# 1   2023-01-02        2077.76
# 2   2023-01-03        3753.49
# 3   2023-01-06         954.38
# 4   2023-01-09         946.44
# 5   2023-01-11         668.12
# 6   2023-01-14         644.82
# 7   2023-01-15         147.94
# 8   2023-01-16        1661.31
# 9   2023-01-17        2176.64
# 10  2023-01-18          41.00
# 11  2023-01-19        1450.44
# 12  2023-01-20        1549.24
# 13  2023-01-22        1969.22
# 14  2023-01-23        2841.16
# 15  2023-01-26        1245.69
# 16  2023-01-27        1166.54
# 17  2023-01-28         436.37
# 18  2023-01-30         793.70
# 19  2023-02-01         985.80
# 20  2023-02-02        5332.69
# ...
